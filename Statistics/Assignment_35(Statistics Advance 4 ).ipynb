# %% [markdown]
# ### Assignment  35: Statistics Advance 4 - Kundan Kumar

# %% [markdown]
# ![image.png](attachment:f3f35fd4-dbc7-4eee-866c-8ed28cde6211.png)

# %% [markdown]
# Answer:
#
# t-test and z-test are both statistical tests that are used to determine whether there is a significant difference between two means. However, they differ in their assumptions about the population variance and the sample size.
#
# A z-test is used when the population variance is known and the sample size is large (usually greater than 30).
#
# Example:
#
#     Suppose a company wants to determine if the average weight of their product is equal to the weight specified on the packaging, which is 50 grams. They take a random sample of 100 products and measure their weights. The population variance of the weights is known to be 4 grams. In this case, a z-test would be appropriate to test the hypothesis that the mean weight of the products is 50 grams.
#
# A t-test is used when the population variance is unknown and the sample size is small (usually less than 30).
# Example:
#
#     Suppose a researcher wants to determine if a new treatment is effective in reducing blood pressure. They randomly assign 20 participants to receive the new treatment or a placebo and measure their blood pressure before and after the treatment. The researcher does not know the population variance of the blood pressure measurements. In this case, a t-test would be appropriate to test the hypothesis that the mean reduction in blood pressure is greater in the treatment group compared to the placebo group.

# %% [markdown]
# ![image.png](attachment:f5ee96f3-44a3-47eb-a2e0-65e65bf5a789.png)

# %% [markdown]
# Answer:
#
# A one-tailed test, also known as a directional test, is a statistical test in which the hypothesis is tested in only one direction. It is used when there is a priori information or a specific prediction about the direction of the difference between two sample groups. The hypothesis is tested either to determine whether the sample mean is greater than or less than a known value, or whether it is different from that value in a particular direction.
#
# A two-tailed test, also known as a non-directional test, is a statistical test in which the hypothesis is tested in both directions. It is used when there is no a priori information or specific prediction about the direction of the difference between two sample groups. The hypothesis is tested to determine whether the sample mean is different from a known value in any direction.

# %% [markdown]
# ![image.png](attachment:d7fea86e-223d-4699-a50e-a763faef1aa3.png)

# %% [markdown]
# Answer:
#
# Type 1 Error:
# A Type 1 error occurs when the null hypothesis is rejected when it should not be. It means that a significant difference is found when there is actually no difference. The probability of making a Type 1 error is denoted by the alpha level, which is typically set at 0.05 or 0.01.
#
# Example:
#
#     Suppose a new drug is tested to see if it is effective in reducing pain. The null hypothesis is that the drug has no effect on pain, but in reality, it does. However, the study concludes that the drug is not effective, and the null hypothesis is rejected, leading to a Type 1 error. This can result in a potentially harmful drug being rejected, leading to patients not receiving the treatment they need.
#
# Type 2 Error:
#
# A Type 2 error occurs when the null hypothesis is not rejected when it should be. It means that no significant difference is found when there is actually a difference. The probability of making a Type 2 error is denoted by the beta level, which is typically set at 0.10 or 0.20.
#
# Example:
#
#     Suppose a new drug is tested to see if it is effective in reducing pain. The null hypothesis is that the drug has no effect on pain, and in reality, it doesn't. However, the study concludes that the drug is effective, and the null hypothesis is not rejected, leading to a Type 2 error. This can result in a potentially ineffective drug being approved, leading to patients receiving a treatment that does not work.

# %% [markdown]
# ![image.png](attachment:2470e4ed-f85a-4209-8b46-44b88c9baefe.png)

# %% [markdown]
# Answer:
#
# Bayes's theorem is a mathematical formula used in probability theory to calculate the conditional probability of an event based on prior knowledge of related events. It provides a way to update the probability of a hypothesis based on new evidence.
#
# The formula for Bayes's theorem is:
#
#     P(A|B) = (P(B|A) * P(A)) / P(B)
#
#     Where:
#     P(A|B) is the probability of event A given that event B has occurred.
#     P(B|A) is the probability of event B given that event A has occurred.
#     P(A) is the prior probability of event A.
#     P(B) is the prior probability of event B.
#
# Example:
#
#     Suppose a doctor knows that the probability of a patient having a certain disease is 0.05. The doctor also knows that if a person has the disease, the probability of a certain test detecting it is 0.95. However, if a person does not have the disease, there is still a 5% chance that the test will produce a false positive result.
#
# If a patient tests positive for the disease, what is the probability that the patient actually has the disease?
#
# Using the formula, we can calculate the probability of the patient having the disease given that they have tested positive as follows:
#
#     P(A|B) = (P(B|A) * P(A)) / (P(B|A) * P(A) + P(B|~A) * P(~A))
#     = (0.95 * 0.05) / (0.95 * 0.05 + 0.05 * 0.95)
#     = 0.5 or 50%

# %% [markdown]
# ![image.png](attachment:871fc6d5-261e-4923-849b-412fa3f8a1cd.png)

# %% [markdown]
# Answer:
#
# A confidence interval is a range of values that is likely to contain the true value of a population parameter with a certain level of confidence. It is used in statistics to estimate an unknown population parameter, such as a mean or proportion, based on a sample of data.
#
#
# The formula for calculating a confidence interval for a population mean is:
#
#     CI = X̄ ± z * (s / sqrt(n))
#
#     Where:
#     CI is the confidence interval
#     X̄ is the sample mean
#     z is the z-score associated with the desired level of confidence (e.g., 1.96 for a 95% confidence interval)
#     s is the sample standard deviation
#     n is the sample size
#
# Example:
#
#     Suppose we want to estimate the mean height of all adult males in a certain population. We take a random sample of 50 adult males and measure their heights. The sample mean height is 175 cm, and the sample standard deviation is 8 cm.
#
# We want to calculate a 95% confidence interval for the population mean height.
#
# First, we need to find the z-score associated with a 95% confidence level. From a standard normal distribution table, we can see that the z-score for a 95% confidence level is 1.96.
#
# Next, we can use the formula to calculate the confidence interval:
#
#     CI = 175 ± 1.96 * (8 / sqrt(50))
#     = 175 ± 2.83
#     = (172.17, 177.83)
#
# Therefore, we can be 95% confident that the true population mean height falls between 172.17 and 177.83 cm.

# %% [markdown]
# ![image.png](attachment:68cedb8d-af07-4ba5-a9eb-999566e4cf98.png)

# %% [markdown]
# Answer:
#
# Suppose a company sells two types of products: product A and product B. Historically, the company has found that 40% of its customers buy product A and 60% buy product B. The company is now introducing a new product, product C, and wants to estimate the probability that a customer will buy it. They conduct a survey of 100 randomly selected customers and find that 30 of them bought product A, 40 bought product B, and 10 bought product C.
#
# Using Bayes' Theorem, we have:
#
#     P(C | data) = P(data | C) * P(C) / P(data)
#
# We can calculate P(data | C), P(C) and P(data) as follows:
#
#     P(data | C) = 10/100 = 0.1, since 10 out of 100 customers bought product C.
#     P(C) = 1/N = 10/100 = 0.1, where N is the total number of customers in the sample.
#     P(data) = P(data | A) * P(A) + P(data | B) * P(B) + P(data | C) * P(C) = (30/100 * 0.4) + (40/100 * 0.6) + (10/100 * 0.1) = 0.34.
#
# Finally, plug the values in the formula as:
#
#     P(C | data) = P(data | C) * P(C) / P(data)
#     = 0.1 * 0.1 / 0.34
#     = 0.029 or about 2.9%
#
# So, based on the survey data, we estimate that the probability that a customer will buy product C is about 2.9%.

# %% [markdown]
# ![image.png](attachment:edd60481-2776-49b9-b4f3-edbf85e3e247.png)

# %% [markdown]
# The final conclusion is:
#
#     The range of values that lie inside 95% confidence interval region are: 49.02 to 50.98
#
# **Detailed answer**
#
#
#
# To calculate the 95% confidence interval for a sample mean, you can use the formula:
#
# Confidence Interval = Sample Mean ± (Z-Score) × (Standard Deviation / √(Sample Size))
#
# Where:
# - Sample Mean (x̄) = 50
# - Z-Score for a 95% confidence level ≈ 1.96
# - Standard Deviation (σ) = 5
# - Sample Size (n) = This information is not provided, but I will assume it's 100 for demonstration purposes.
#
# Calculate the confidence interval:
#
# Confidence Interval = 50 ± (1.96) × (5 / √100)
#
# Confidence Interval = 50 ± (1.96) × 0.5
#
# Confidence Interval ≈ 50 ± 0.98
#
# So, the 95% confidence interval for the sample mean is approximately (49.02, 50.98).
#
# Interpretation:
# This confidence interval suggests that we are 95% confident that the true population mean lies between 49.02 and 50.98. In other words, if we were to take multiple samples and calculate their confidence intervals, we would expect about 95% of those intervals to contain the true population mean. The larger the sample size, the narrower the confidence interval becomes, reflecting greater confidence in the estimated range of the true population mean.

# %% [markdown]
# ![image.png](attachment:8cd95be9-08a7-4e82-90aa-3dc1bc7a776a.png)

# %% [markdown]
# Answer:
# The margin of error is a measure of the uncertainty in an estimated population parameter based on a sample. It is the range of values around the point estimate that is likely to contain the true population parameter with a certain level of confidence.
#
# Sample size affects the margin of error in that a larger sample size will generally result in a smaller margin of error. This is because a larger sample size provides more information about the population and reduces the impact of random sampling variability on the point estimate. Specifically, the margin of error decreases as the square root of the sample size increases.
#
# Example:
#
#     Suppose we want to estimate the proportion of people in a city who support a certain policy. We take a random sample of 500 people and find that 60% of them support the policy. We also calculate a 95% confidence interval with a margin of error of 4%. This means that we are 95% confident that the true proportion of people who support the policy in the city falls between 56% and 64%.
#
#     Now, suppose we increase the sample size to 1000. We recalculate the point estimate as 60% and the margin of error as 2.8%. This means that we are 95% confident that the true proportion of people who support the policy in the city falls between 57.2% and 62.8%. As we can see, a larger sample size has resulted in a smaller margin of error and a narrower confidence interval

# %% [markdown]
# ![image.png](attachment:ddd300ba-d6f1-4ac3-9b53-ddded79dde2f.png)

# %% [markdown]
# Answer:
#
# The z-score is a measure of how many standard deviations a particular data point is away from the mean of the population. It is calculated using the formula:
#
#     z = (x - μ) / σ
#
#     Where:
#
#     x is the data point's value (75 in this case)
#     μ is the population mean (70 in this case)
#     σ is the population standard deviation (5 in this case)
#     Let's plug in the values and calculate the z-score:
#
#     z = (75 - 70) / 5
#     z = 1
#
# Interpretation:
#
#     The calculated z-score of 1 indicates that the data point with a value of 75 is 1 standard deviation above the population mean of 70.
#     In other words, this data point is higher than the average value by an amount equal to one standard deviation. This provides context about how "unusual" or "normal" the data point's value is compared to the rest of the population. Since the z-score is positive, we can conclude that the data point is above the mean.

# %% [markdown]
# ![image.png](attachment:f9cb3143-a502-496d-aded-74b0fc9890b0.png)

# %% [markdown]
# Answer:
#
#     To conduct a hypothesis test using a t-test, we'll follow these steps:
#
# 1. **Formulate Hypotheses:**
#    - Null Hypothesis (H₀): The new weight loss drug is not significantly effective. (μ = μ₀)
#    - Alternative Hypothesis (H₁): The new weight loss drug is significantly effective. (μ ≠ μ₀)
#
# 2. **Choose Significance Level:**
#
#    Let's use a significance level of 0.05 (or 5%).
#
# 3. **Calculate the Test Statistic:**
#
#    The formula for the t-test statistic is:
#
#    t = (x̄ - μ₀) / (s / √n)
#
#    Where:
#    - x̄ is the sample mean (6 pounds)
#    - μ₀ is the hypothesized population mean (you didn't provide this, let's say 0 pounds for no effect)
#    - s is the sample standard deviation (2.5 pounds)
#    - n is the sample size (50 participants)
#
#    Plugging in the values:
#
#    t = (6 - 0) / (2.5 / √50)
#    t = 30 / 0.3536
#    t ≈ 84.75
#
# 4. **Calculate Degrees of Freedom:**
#
#    Degrees of freedom (df) = n - 1 = 50 - 1 = 49
#
# 5. **Find Critical Value:**
#
#    At a 95% confidence level and with 49 degrees of freedom, you can find the critical t-value using a t-table or calculator. For a two-tailed test, the critical t-value would be approximately ±2.0096.
#
# 6. **Compare Test Statistic and Critical Value:**
#
#    Since the test statistic (84.75) is much larger than the critical value (2.0096), we can reject the null hypothesis.
#
# 7. **Make a Decision:**
#
#    Based on the results, we reject the null hypothesis. This suggests that the new weight loss drug is significantly effective at a 95% confidence level.
#
# 8. **Interpretation:**
#
#    At a 95% confidence level, the data provides strong evidence to support the conclusion that the new weight loss drug is significantly effective in helping participants lose weight. The sample mean of 6 pounds is significantly different from the hypothesized mean of 0 pounds, and this difference is unlikely to have occurred by chance.

# %% [markdown]
# ![image.png](attachment:b2d2d85c-c95e-41d4-83f2-ac5195a85f12.png)

# %% [markdown]
# To calculate the 95% confidence interval for a proportion, you can use the formula:
#
# Confidence Interval = Sample Proportion ± (Z-Score) × Standard Error
#
# Where:
# - Sample Proportion (p̂) = 65% = 0.65
# - Z-Score corresponding to a 95% confidence level ≈ 1.96 (for a large enough sample size)
# - Standard Error (SE) = √[(p̂ * (1 - p̂)) / n], where n is the sample size
#
# Given that you have a sample size of 500:
#
# Sample Proportion (p̂) = 0.65
# Z-Score = 1.96 (for a 95% confidence level)
# Sample Size (n) = 500
#
# Calculate the standard error:
# SE = √[(0.65 * (1 - 0.65)) / 500]
# SE ≈ 0.0229
#
# Calculate the confidence interval:
#
# Confidence Interval = 0.65 ± (1.96) × 0.0229
#
# Now plug in the values:
#
# Confidence Interval ≈ 0.65 ± 0.0449
#
# So, the 95% confidence interval for the true proportion of people who are satisfied with their job is approximately (0.6051, 0.6949).
#
# Interpretation:
# This confidence interval suggests that we are 95% confident that the true proportion of people who are satisfied with their job lies between 60.51% and 69.49%. In other words, if we were to take multiple samples and calculate their confidence intervals, we would expect about 95% of those intervals to contain the true population proportion. The larger the sample size, the narrower the confidence interval becomes, reflecting greater confidence in the estimated range of the true proportion.

# %% [markdown]
# ![image.png](attachment:52a8a6f9-e467-4e56-91e8-acfc601df761.png)

# %% [markdown]
# Answer:
#
# Final answer is:
#
#     Failed to reject null hypothesis
#     No significant difference in students performance between the two teaching methods
#
# **Detailed Solution**
#
# To conduct a hypothesis test to determine if there is a significant difference in student performance between two teaching methods, we'll use a two-sample independent t-test. Here are the steps:
#
# 1. **Formulate Hypotheses:**
#    - Null Hypothesis (H₀): There is no significant difference in student performance between the two teaching methods. (μ₁ - μ₂ = 0)
#    - Alternative Hypothesis (H₁): There is a significant difference in student performance between the two teaching methods. (μ₁ - μ₂ ≠ 0)
#
# 2. **Choose Significance Level:**
#    The significance level is given as 0.01.
#
# 3. **Calculate the Test Statistic:**
#    The formula for the two-sample independent t-test statistic is:
#
#    t = (x̄₁ - x̄₂) / √((s₁² / n₁) + (s₂² / n₂))
#
#    Where:
#    - x̄₁ is the mean score for sample A (85)
#    - x̄₂ is the mean score for sample B (82)
#    - s₁ is the standard deviation for sample A (6)
#    - s₂ is the standard deviation for sample B (5)
#    - n₁ is the sample size for sample A
#    - n₂ is the sample size for sample B
#
#    Since the sample sizes are not given, I'll assume they are both 30 for demonstration purposes:
#
#    t = (85 - 82) / √((6² / 30) + (5² / 30))
#    t = 3 / √(1.44 + 0.8333)
#    t ≈ 3 / 1.5799
#    t ≈ 1.8968
#
# 4. **Calculate Degrees of Freedom:**
#    Degrees of freedom (df) = n₁ + n₂ - 2 = 30 + 30 - 2 = 58
#
# 5. **Find Critical Value:**
#    For a two-tailed test at a significance level of 0.01 and 58 degrees of freedom, you can find the critical t-value using a t-table or calculator. The critical t-value would be approximately ±2.660.
#
# 6. **Compare Test Statistic and Critical Value:**
#    Since the absolute value of the test statistic (1.8968) is smaller than the critical value (2.660), we fail to reject the null hypothesis.
#
# 7. **Make a Decision:**
#    Based on the results, we do not have sufficient evidence to conclude that there is a significant difference in student performance between the two teaching methods at the 0.01 significance level.
#
# 8. **Interpretation:**
#    The data does not provide enough evidence to support the claim that there is a significant difference in student performance between the two teaching methods.

# %% [markdown]
# ![image.png](attachment:e04bd6a4-31b4-474b-8927-fc9b62543f38.png)

# %% [markdown]
# To calculate the 90% confidence interval for the true population mean, you can use the formula:
#
# Confidence Interval = Sample Mean ± (Z-Score) × (Standard Deviation / √(Sample Size))
#
# Where:
#     - Sample Mean (x̄) = 65
#     - Z-Score for a 90% confidence level ≈ 1.645 (for a one-tailed test)
#     - Standard Deviation (σ) = 8
#     - Sample Size (n) = 50
#
# Calculate the confidence interval:
#
#     Confidence Interval = 65 ± (1.645) × (8 / √50)
#
#     Confidence Interval = 65 ± (1.645) × 1.1313708499
#
#     Confidence Interval ≈ 65 ± 1.861906534
#
# So, the 90% confidence interval for the true population mean is approximately (63.14, 66.86).
#
# Interpretation:
#
#     This confidence interval indicates that we are 90% confident that the true population mean lies between 63.14 and 66.86. In other words, if we were to take multiple samples and calculate their confidence intervals, we would expect about 90% of those intervals to contain the true population mean. The larger the sample size, the narrower the confidence interval becomes, reflecting greater confidence in the estimated range of the true population mean.

# %% [markdown]
# ![image.png](attachment:8a2f7815-45b8-4c26-a2fb-7062223825bb.png)

# %% [markdown]
# Final answer is:
#
#     Failed to reject null hypothesis
#     Caffeine has no significant affect on reaction time
#
# To conduct a hypothesis test to determine if caffeine has a significant effect on reaction time, we'll use a t-test for a single sample. Here are the steps:
#
# 1. **Formulate Hypotheses:**
#    - Null Hypothesis (H₀): Caffeine does not have a significant effect on reaction time. (μ = μ₀)
#    - Alternative Hypothesis (H₁): Caffeine has a significant effect on reaction time. (μ ≠ μ₀)
#
# 2. **Choose Significance Level:**
#    The significance level is given as 90%, which corresponds to a 0.10 significance level since the complement of 90% is 10%.
#
# 3. **Calculate the Test Statistic:**
#    The formula for the t-test statistic for a single sample is:
#
#    t = (x̄ - μ₀) / (s / √n)
#
#    Where:
#    - x̄ is the sample mean reaction time (0.25 seconds)
#    - μ₀ is the hypothesized population mean reaction time (you didn't provide this, so I'll assume it's 0.20 seconds for demonstration purposes)
#    - s is the sample standard deviation (0.05 seconds)
#    - n is the sample size (30 participants)
#
#    Plugging in the values:
#
#    t = (0.25 - 0.20) / (0.05 / √30)
#    t = 0.05 / 0.00912870929
#    t ≈ 5.4722
#
# 4. **Calculate Degrees of Freedom:**
#    Degrees of freedom (df) = n - 1 = 30 - 1 = 29
#
# 5. **Find Critical Value:**
#    For a two-tailed test at a significance level of 0.10 and 29 degrees of freedom, you can find the critical t-value using a t-table or calculator. The critical t-value would be approximately ±1.645.
#
# 6. **Compare Test Statistic and Critical Value:**
#    Since the absolute value of the test statistic (5.4722) is much larger than the critical value (1.645), we can reject the null hypothesis.
#
# 7. **Make a Decision:**
#    Based on the results, we reject the null hypothesis. This suggests that caffeine has a significant effect on reaction time at the 90% confidence level.
#
# 8. **Interpretation:**
#    At a 90% confidence level, the data provides strong evidence to support the conclusion that caffeine has a significant effect on reaction time. The sample mean reaction time of 0.25 seconds is significantly different from the hypothesized mean of 0.20 seconds, and this difference is unlikely to have occurred by chance.
